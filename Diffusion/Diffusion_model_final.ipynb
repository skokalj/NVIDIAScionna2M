# %%
import os, sys, time
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

sys.path.insert(0, "/home/silvija/saiteja")
OUT_DIR  = "/data/silvija/diffusion_results"
zr_path  = os.path.join(OUT_DIR, "zr_features.npy")          
xml_path = os.path.join(OUT_DIR, "xml_features_proj.npy")
# Out:
# device: cuda

# %%
from clip_model import SceneClipModelPad

CLIP_CKPT = "/home/silvija/saiteja/lightning_logs/version_7/checkpoints/epoch=299-step=2400.ckpt"  
clip = SceneClipModelPad(projected_emb_dim=128, num_fc_layers=2).to(device)

ckpt = torch.load(CLIP_CKPT, map_location="cpu")
state = ckpt["state_dict"] if (isinstance(ckpt, dict) and "state_dict" in ckpt) else ckpt
missing, unexpected = clip.load_state_dict(state, strict=True)
print("Missing:", len(missing))
print("Unexpected:", len(unexpected))

clip.eval()
for p in clip.parameters():
    p.requires_grad_(False)
print("CLIP Frozen")
print("zr_projection:\n", clip.zr_projection)
# Out:
# Missing: 0
# Unexpected: 0
# CLIP Frozen
# zr_projection:
#  ProjectionHead(
#   (layers): ModuleList(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (projection): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=128, out_features=128, bias=True)
#   )
# )

# %%
class ZFeatDataset(Dataset):
    def __init__(self, zr_path, xml_proj_path):
        zr   = np.ascontiguousarray(np.load(zr_path), dtype=np.float32)
        xmlp = np.ascontiguousarray(np.load(xml_proj_path), dtype=np.float32)
        assert zr.shape[0] == xmlp.shape[0], (zr.shape, xmlp.shape)
        assert zr.shape[1] == 128, zr.shape
        assert xmlp.shape[1] == 64,  xmlp.shape
        self.zr   = torch.from_numpy(zr)
        self.xmlp = torch.from_numpy(xmlp)

    def __len__(self):
        return self.zr.shape[0]

    def __getitem__(self, idx):
        return self.xmlp[idx], self.zr[idx]

ds = ZFeatDataset(zr_path, xml_path)
print("Dataset size:", len(ds))
# Out:
# Dataset size: 10000

# %%
def linear_beta_schedule(T, beta_start=1e-4, beta_end=0.02, device="cpu"):
    betas = torch.linspace(beta_start, beta_end, T, device=device)
    alphas = 1.0 - betas
    abar = torch.cumprod(alphas, dim=0)
    return betas, alphas, abar

def extract(a, t, x_shape):
    out = a.gather(0, t)  # [B]
    while len(out.shape) < len(x_shape):
        out = out.unsqueeze(-1)
    return out

class ConditionalVectorDDPM(nn.Module):
    def __init__(self, denoiser: nn.Module, T: int = 300):
        super().__init__()
        self.denoiser = denoiser
        self.T = T
        self._schedule_set = False

    def set_schedule(self, device):
        betas, alphas, abar = linear_beta_schedule(self.T, device=device)
        self.register_buffer("betas", betas)
        self.register_buffer("alphas", alphas)
        self.register_buffer("abar", abar)
        self.register_buffer("sqrt_abar", torch.sqrt(abar))
        self.register_buffer("sqrt_1m_abar", torch.sqrt(1.0 - abar))
        self.register_buffer("sqrt_recip_abar", torch.sqrt(1.0 / abar))
        self.register_buffer("sqrt_recipm1_abar", torch.sqrt(1.0 / abar - 1.0))
        self._schedule_set = True

    # q(x_t | x0) = sqrt(abar)*x0 + sqrt(1-abar)*noise
    def q_sample(self, x0, t, noise):
        return (
            extract(self.sqrt_abar, t, x0.shape) * x0
            + extract(self.sqrt_1m_abar, t, x0.shape) * noise
        )

    # x0_hat = (x_t - sqrt(1-abar)*eps) / sqrt(abar)
    def predict_x0_from_eps(self, x_t, t, eps):
        return (
            extract(self.sqrt_recip_abar, t, x_t.shape) * x_t
            - extract(self.sqrt_recipm1_abar, t, x_t.shape) * eps
        )

    def forward_train(self, x0, context):
        B = x0.shape[0]
        t = torch.randint(0, self.T, (B,), device=x0.device, dtype=torch.long)
        noise = torch.randn_like(x0)
        x_t = self.q_sample(x0, t, noise)
        pred_noise = self.denoiser(x_t, t, context)
        x0_hat = self.predict_x0_from_eps(x_t, t, pred_noise)
        return pred_noise, noise, x_t, t, x0_hat

    @torch.no_grad()
    def p_sample(self, x_t, t, context):
        eps = self.denoiser(x_t, t, context)
        x0_hat = self.predict_x0_from_eps(x_t, t, eps)

        beta_t = extract(self.betas, t, x_t.shape)
        alpha_t = extract(self.alphas, t, x_t.shape)
        abar_t = extract(self.abar, t, x_t.shape)
        abar_prev = extract(self.abar, (t - 1).clamp(min=0), x_t.shape)

        mean = (
            (torch.sqrt(abar_prev) * beta_t / (1.0 - abar_t)) * x0_hat
            + (torch.sqrt(alpha_t) * (1.0 - abar_prev) / (1.0 - abar_t)) * x_t
        )

        if (t == 0).all():
            return x0_hat

        noise = torch.randn_like(x_t)
        var = beta_t * (1.0 - abar_prev) / (1.0 - abar_t)
        return mean + torch.sqrt(var.clamp(min=1e-20)) * noise

    @torch.no_grad()
    def sample(self, context, shape):
        x = torch.randn(shape, device=context.device)
        for ti in reversed(range(self.T)):
            t = torch.full((shape[0],), ti, device=context.device, dtype=torch.long)
            x = self.p_sample(x, t, context)
        return x

# %%
class ResBlock(nn.Module):
    def __init__(self, ch):
        super().__init__()
        self.conv1 = nn.Conv1d(ch, ch, 3, padding=1)
        self.conv2 = nn.Conv1d(ch, ch, 3, padding=1)
        self.norm1 = nn.GroupNorm(8, ch)
        self.norm2 = nn.GroupNorm(8, ch)

    def forward(self, x):
        h = self.conv1(x)
        h = self.norm1(h)
        h = F.silu(h)
        h = self.conv2(h)
        h = self.norm2(h)
        return F.silu(x + h)

class CondDenoiserConv(nn.Module):
    def __init__(self, x_dim=128, ctx_dim=128, ch=64, emb_dim=256, T=300):
        super().__init__()
        self.T = T

        self.in_conv = nn.Conv1d(1, ch, 3, padding=1)

        self.time_embed = nn.Sequential(
            nn.Linear(1, emb_dim),
            nn.SiLU(),
            nn.Linear(emb_dim, emb_dim),
        )
        self.ctx_embed = nn.Sequential(
            nn.Linear(ctx_dim, emb_dim),
            nn.SiLU(),
            nn.Linear(emb_dim, emb_dim),
        )

        self.to_film = nn.Linear(emb_dim, 2 * ch)

        self.block1 = ResBlock(ch)
        self.block2 = ResBlock(ch)
        self.block3 = ResBlock(ch)

        self.out_conv = nn.Conv1d(ch, 1, 3, padding=1)

    def forward(self, x_t, t, context):
        # x_t: [B,128], context: [B,128]
        x = x_t.unsqueeze(1)  # [B,1,128]

        t_norm = (t.float() / (self.T - 1)).unsqueeze(-1)  # [B,1]
        emb = self.time_embed(t_norm) + self.ctx_embed(context)  # [B,emb_dim]

        gamma, beta = self.to_film(emb).chunk(2, dim=-1)  # [B,ch], [B,ch]
        gamma = gamma.unsqueeze(-1)  # [B,ch,1]
        beta  = beta.unsqueeze(-1)   # [B,ch,1]

        h = self.in_conv(x)                # [B,ch,128]
        h = h * (1 + gamma) + beta         # FiLM

        h = self.block1(h)
        h = self.block2(h)
        h = self.block3(h)

        out = self.out_conv(h)             # [B,1,128]
        return out.squeeze(1)              # [B,128]

# %%
def cosine_alignment_loss(a, b):
    a = F.normalize(a, dim=-1)
    b = F.normalize(b, dim=-1)
    return (1.0 - F.cosine_similarity(a, b, dim=-1)).mean()

# %%
T = 300
CTX_DIM = 128

denoiser = CondDenoiserConv(x_dim=128, ctx_dim=CTX_DIM, T=T).to(device)
diffusion = ConditionalVectorDDPM(denoiser, T=T).to(device)
diffusion.set_schedule(device)

LAM_MSE = 0.1
LAM_COS = 0.1
print("LAM_MSE:", LAM_MSE, "LAM_COS:", LAM_COS)

opt = torch.optim.AdamW(denoiser.parameters(), lr=2e-4, weight_decay=1e-4)

# Split + loaders
g = torch.Generator().manual_seed(42)
n_total = len(ds)
n_val = int(0.1 * n_total)
n_train = n_total - n_val
train_ds, val_ds = random_split(ds, [n_train, n_val], generator=g)

dl_train = DataLoader(train_ds, batch_size=256, shuffle=True,  drop_last=True,  num_workers=4, pin_memory=True)
dl_val   = DataLoader(val_ds,   batch_size=256, shuffle=False, drop_last=False, num_workers=4, pin_memory=True)

print("Train size:", len(train_ds), "Val size:", len(val_ds))


epochs = 300
CKPT_DIR = os.path.join(OUT_DIR, "diffusion_ckpts")
os.makedirs(CKPT_DIR, exist_ok=True)

train_total_losses, val_total_losses = [], []
train_mse_losses, train_cos_losses = [], []
val_mse_losses, val_cos_losses = [], []

start_train_time = time.time()
step = 0

for ep in range(1, epochs + 1):
    denoiser.train()

    tr_total_sum = tr_mse_sum = tr_cos_sum = 0.0
    tr_n = 0

    # ---- TRAIN ----
    for xml_proj, zr_feat in dl_train:
        xml_proj = xml_proj.to(device, non_blocking=True)  # [B,64]
        zr_feat  = zr_feat.to(device, non_blocking=True)   # [B,128]

        # Context from CLIP 
        with torch.no_grad():
            xml_ctx = clip.xml_projection(clip.xml_encoder(xml_proj))  # [B,128]
            xml_ctx = F.normalize(xml_ctx, dim=-1)

        pred_noise, true_noise, x_t, t, x0_hat = diffusion.forward_train(zr_feat, xml_ctx)

        loss_mse = F.mse_loss(pred_noise, true_noise)

        zr_enc_hat = clip.zr_encoder(x0_hat)          # [B,128]
        zr_enc_hat = F.normalize(zr_enc_hat, dim=-1)

        loss_cos = cosine_alignment_loss(zr_enc_hat, xml_ctx)
        loss = LAM_MSE * loss_mse + LAM_COS * loss_cos

        opt.zero_grad(set_to_none=True)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(denoiser.parameters(), 1.0)
        opt.step()

        bs = zr_feat.shape[0]
        tr_total_sum += loss.item() * bs
        tr_mse_sum   += loss_mse.item() * bs
        tr_cos_sum   += loss_cos.item() * bs
        tr_n += bs

        if step % 50 == 0:
            with torch.no_grad():
                cos = F.cosine_similarity(zr_enc_hat, xml_ctx, dim=-1).mean().item()
            print(f"ep {ep} step {step} | mse {loss_mse.item():.4f} | cosLoss {loss_cos.item():.4f} | cos {cos:.4f} | total {loss.item():.4f}")

        step += 1

    tr_total = tr_total_sum / max(1, tr_n)
    tr_mse   = tr_mse_sum   / max(1, tr_n)
    tr_cos   = tr_cos_sum   / max(1, tr_n)

    train_total_losses.append(tr_total)
    train_mse_losses.append(tr_mse)
    train_cos_losses.append(tr_cos)

    # ---- VAL ----
    denoiser.eval()
    va_total_sum = va_mse_sum = va_cos_sum = 0.0
    va_n = 0

    with torch.no_grad():
        for xml_proj, zr_feat in dl_val:
            xml_proj = xml_proj.to(device, non_blocking=True)
            zr_feat  = zr_feat.to(device, non_blocking=True)

            xml_ctx = clip.xml_projection(clip.xml_encoder(xml_proj))
            xml_ctx = F.normalize(xml_ctx, dim=-1)

            pred_noise, true_noise, x_t, t, x0_hat = diffusion.forward_train(zr_feat, xml_ctx)

            loss_mse = F.mse_loss(pred_noise, true_noise)

            zr_enc_hat = F.normalize(clip.zr_encoder(x0_hat), dim=-1)
            loss_cos = cosine_alignment_loss(zr_enc_hat, xml_ctx)

            loss = LAM_MSE * loss_mse + LAM_COS * loss_cos

            bs = zr_feat.shape[0]
            va_total_sum += loss.item() * bs
            va_mse_sum   += loss_mse.item() * bs
            va_cos_sum   += loss_cos.item() * bs
            va_n += bs

    va_total = va_total_sum / max(1, va_n)
    va_mse   = va_mse_sum   / max(1, va_n)
    va_cos   = va_cos_sum   / max(1, va_n)

    val_total_losses.append(va_total)
    val_mse_losses.append(va_mse)
    val_cos_losses.append(va_cos)

    print(f"[EP {ep:03d}] train_total={tr_total:.6f} | val_total={va_total:.6f} | train_cos={tr_cos:.6f} | val_cos={va_cos:.6f}")

    ckpt_path = os.path.join(CKPT_DIR, f"denoiser_ep{ep}.pt")
    torch.save({"denoiser": denoiser.state_dict(), "T": T, "LAM_MSE": LAM_MSE, "LAM_COS": LAM_COS}, ckpt_path)

train_elapsed = time.time() - start_train_time
print(f"\nTRAINED FOR: {epochs} epochs")
print(f"TRAINING TIME: {train_elapsed/60:.2f} minutes ({train_elapsed:.1f} seconds)")
print("Last ckpt dir:", CKPT_DIR)
# Out:
# LAM_MSE: 0.1 LAM_COS: 0.1
# Train size: 9000 Val size: 1000
# ep 1 step 0 | mse 2.0859 | cosLoss 1.0051 | cos -0.0051 | total 0.3091
# [EP 001] train_total=0.122670 | val_total=0.104979 | train_cos=0.986303 | val_cos=0.963557
# ep 2 step 50 | mse 0.0750 | cosLoss 0.9522 | cos 0.0478 | total 0.1027
# [EP 002] train_total=0.103881 | val_total=0.102651 | train_cos=0.950409 | val_cos=0.942293
# ep 3 step 100 | mse 0.1061 | cosLoss 0.9295 | cos 0.0705 | total 0.1036
# [EP 003] train_total=0.101896 | val_total=0.100425 | train_cos=0.933094 | val_cos=0.926426
# [EP 004] train_total=0.099972 | val_total=0.099158 | train_cos=0.921341 | val_cos=0.912245
# ep 5 step 150 | mse 0.0706 | cosLoss 0.9058 | cos 0.0942 | total 0.0976
# [EP 005] train_total=0.098371 | val_total=0.098083 | train_cos=0.907734 | val_cos=0.904113
# ep 6 step 200 | mse 0.0656 | cosLoss 0.9010 | cos 0.0990 | total 0.0967
# [EP 006] train_total=0.097941 | val_total=0.095527 | train_cos=0.903056 | val_cos=0.895136
# [EP 007] train_total=0.098600 | val_total=0.097091 | train_cos=0.909987 | val_cos=0.900364
# ep 8 step 250 | mse 0.0737 | cosLoss 0.8931 | cos 0.1069 | total 0.0967
# [EP 008] train_total=0.096450 | val_total=0.096903 | train_cos=0.894635 | val_cos=0.891033
# ep 9 step 300 | mse 0.0638 | cosLoss 0.8886 | cos 0.1114 | total 0.0952
# [EP 009] train_total=0.096220 | val_total=0.095705 | train_cos=0.889134 | val_cos=0.888977
# [EP 010] train_total=0.096139 | val_total=0.096796 | train_cos=0.891286 | val_cos=0.890301
# ep 11 step 350 | mse 0.0649 | cosLoss 0.8896 | cos 0.1104 | total 0.0954
# [EP 011] train_total=0.096144 | val_total=0.096267 | train_cos=0.889162 | val_cos=0.885413
# ep 12 step 400 | mse 0.0647 | cosLoss 0.8851 | cos 0.1149 | total 0.0950
# [EP 012] train_total=0.095890 | val_total=0.095547 | train_cos=0.885774 | val_cos=0.891344
# ep 13 step 450 | mse 0.0714 | cosLoss 0.9070 | cos 0.0930 | total 0.0978
# [EP 013] train_total=0.096618 | val_total=0.096012 | train_cos=0.894722 | val_cos=0.890736
# [EP 014] train_total=0.096457 | val_total=0.095821 | train_cos=0.890907 | val_cos=0.884229
# ep 15 step 500 | mse 0.0684 | cosLoss 0.8830 | cos 0.1170 | total 0.0951
# [EP 015] train_total=0.095592 | val_total=0.095793 | train_cos=0.885302 | val_cos=0.883854
# ep 16 step 550 | mse 0.0989 | cosLoss 0.8834 | cos 0.1166 | total 0.0982
# [EP 016] train_total=0.095254 | val_total=0.094511 | train_cos=0.882227 | val_cos=0.879707
# [EP 017] train_total=0.094970 | val_total=0.094346 | train_cos=0.879802 | val_cos=0.879932
# ep 18 step 600 | mse 0.0869 | cosLoss 0.8807 | cos 0.1193 | total 0.0968
# [EP 018] train_total=0.095272 | val_total=0.093830 | train_cos=0.880019 | val_cos=0.878364
# ep 19 step 650 | mse 0.0687 | cosLoss 0.8799 | cos 0.1201 | total 0.0949
# [EP 019] train_total=0.095174 | val_total=0.096881 | train_cos=0.881208 | val_cos=0.889261
# [EP 020] train_total=0.095314 | val_total=0.095704 | train_cos=0.883029 | val_cos=0.885820
# ep 21 step 700 | mse 0.0533 | cosLoss 0.8842 | cos 0.1158 | total 0.0937
# [EP 021] train_total=0.094745 | val_total=0.094873 | train_cos=0.878277 | val_cos=0.877052
# ep 22 step 750 | mse 0.0760 | cosLoss 0.8836 | cos 0.1164 | total 0.0960
# [EP 022] train_total=0.094818 | val_total=0.094777 | train_cos=0.878836 | val_cos=0.878087
# ep 23 step 800 | mse 0.0732 | cosLoss 0.8813 | cos 0.1187 | total 0.0954
# [EP 023] train_total=0.095086 | val_total=0.095757 | train_cos=0.883219 | val_cos=0.890083
# [EP 024] train_total=0.095190 | val_total=0.095150 | train_cos=0.880259 | val_cos=0.877757
# ep 25 step 850 | mse 0.0712 | cosLoss 0.8776 | cos 0.1224 | total 0.0949
# [EP 025] train_total=0.094822 | val_total=0.094727 | train_cos=0.879229 | val_cos=0.882122
# ep 26 step 900 | mse 0.0607 | cosLoss 0.8764 | cos 0.1236 | total 0.0937
# [EP 026] train_total=0.094650 | val_total=0.095456 | train_cos=0.877304 | val_cos=0.881326
# [EP 027] train_total=0.094158 | val_total=0.093843 | train_cos=0.877414 | val_cos=0.876251
# ep 28 step 950 | mse 0.0799 | cosLoss 0.8772 | cos 0.1228 | total 0.0957
# [EP 028] train_total=0.094615 | val_total=0.094069 | train_cos=0.877023 | val_cos=0.876797
# ep 29 step 1000 | mse 0.0587 | cosLoss 0.8791 | cos 0.1209 | total 0.0938
# [EP 029] train_total=0.094469 | val_total=0.094228 | train_cos=0.877410 | val_cos=0.876229
# [EP 030] train_total=0.094710 | val_total=0.093843 | train_cos=0.878183 | val_cos=0.876747
# ep 31 step 1050 | mse 0.0615 | cosLoss 0.8762 | cos 0.1238 | total 0.0938
# [EP 031] train_total=0.094662 | val_total=0.094561 | train_cos=0.878852 | val_cos=0.879984
# ep 32 step 1100 | mse 0.0948 | cosLoss 0.8780 | cos 0.1220 | total 0.0973
# [EP 032] train_total=0.094137 | val_total=0.094797 | train_cos=0.875676 | val_cos=0.877378
# ep 33 step 1150 | mse 0.0523 | cosLoss 0.8736 | cos 0.1264 | total 0.0926
# [EP 033] train_total=0.094422 | val_total=0.092851 | train_cos=0.877095 | val_cos=0.873981
# [EP 034] train_total=0.094339 | val_total=0.093931 | train_cos=0.875634 | val_cos=0.874720
# ep 35 step 1200 | mse 0.0661 | cosLoss 0.8783 | cos 0.1217 | total 0.0944
# [EP 035] train_total=0.094331 | val_total=0.094182 | train_cos=0.876210 | val_cos=0.874534
# ep 36 step 1250 | mse 0.0477 | cosLoss 0.8920 | cos 0.1080 | total 0.0940
# [EP 036] train_total=0.096031 | val_total=0.101575 | train_cos=0.894249 | val_cos=0.937934
# [EP 037] train_total=0.097132 | val_total=0.094761 | train_cos=0.900376 | val_cos=0.878702
# ep 38 step 1300 | mse 0.0487 | cosLoss 0.8872 | cos 0.1128 | total 0.0936
# [EP 038] train_total=0.094954 | val_total=0.094528 | train_cos=0.881714 | val_cos=0.876556
# ep 39 step 1350 | mse 0.0788 | cosLoss 0.8761 | cos 0.1239 | total 0.0955
# [EP 039] train_total=0.095114 | val_total=0.094958 | train_cos=0.881700 | val_cos=0.878279
# [EP 040] train_total=0.095021 | val_total=0.093682 | train_cos=0.880116 | val_cos=0.876072
# ep 41 step 1400 | mse 0.0527 | cosLoss 0.8759 | cos 0.1241 | total 0.0929
# [EP 041] train_total=0.093728 | val_total=0.093291 | train_cos=0.874194 | val_cos=0.873549
# ep 42 step 1450 | mse 0.0581 | cosLoss 0.8740 | cos 0.1260 | total 0.0932
# [EP 042] train_total=0.093951 | val_total=0.093872 | train_cos=0.873948 | val_cos=0.873876
# ep 43 step 1500 | mse 0.0625 | cosLoss 0.8740 | cos 0.1260 | total 0.0937
# [EP 043] train_total=0.094217 | val_total=0.093846 | train_cos=0.874889 | val_cos=0.874726
# [EP 044] train_total=0.094645 | val_total=0.093806 | train_cos=0.879420 | val_cos=0.877035
# ep 45 step 1550 | mse 0.0516 | cosLoss 0.8940 | cos 0.1060 | total 0.0946
# [EP 045] train_total=0.094827 | val_total=0.095396 | train_cos=0.880920 | val_cos=0.881067
# ep 46 step 1600 | mse 0.0655 | cosLoss 0.8760 | cos 0.1240 | total 0.0941
# [EP 046] train_total=0.094664 | val_total=0.094188 | train_cos=0.879861 | val_cos=0.875665
# [EP 047] train_total=0.093880 | val_total=0.094193 | train_cos=0.874339 | val_cos=0.874142
# ep 48 step 1650 | mse 0.0568 | cosLoss 0.8730 | cos 0.1270 | total 0.0930
# [EP 048] train_total=0.093702 | val_total=0.094395 | train_cos=0.873221 | val_cos=0.873972
# ep 49 step 1700 | mse 0.0816 | cosLoss 0.8741 | cos 0.1259 | total 0.0956
# [EP 049] train_total=0.094386 | val_total=0.093523 | train_cos=0.874090 | val_cos=0.873001
# [EP 050] train_total=0.093920 | val_total=0.094953 | train_cos=0.873577 | val_cos=0.874870
# ep 51 step 1750 | mse 0.0729 | cosLoss 0.8755 | cos 0.1245 | total 0.0948
# [EP 051] train_total=0.093839 | val_total=0.094808 | train_cos=0.874183 | val_cos=0.874407
# ep 52 step 1800 | mse 0.0754 | cosLoss 0.8739 | cos 0.1261 | total 0.0949
# [EP 052] train_total=0.094098 | val_total=0.093747 | train_cos=0.873791 | val_cos=0.873259
# ep 53 step 1850 | mse 0.0584 | cosLoss 0.8737 | cos 0.1263 | total 0.0932
# [EP 053] train_total=0.093891 | val_total=0.094574 | train_cos=0.873904 | val_cos=0.874650
# [EP 054] train_total=0.094136 | val_total=0.093741 | train_cos=0.874073 | val_cos=0.872845
# ep 55 step 1900 | mse 0.0726 | cosLoss 0.8736 | cos 0.1264 | total 0.0946
# [EP 055] train_total=0.094220 | val_total=0.093263 | train_cos=0.873647 | val_cos=0.873169
# ep 56 step 1950 | mse 0.0481 | cosLoss 0.8744 | cos 0.1256 | total 0.0922
# [EP 056] train_total=0.094060 | val_total=0.095056 | train_cos=0.873952 | val_cos=0.875104
# [EP 057] train_total=0.093488 | val_total=0.093050 | train_cos=0.873205 | val_cos=0.872240
# ep 58 step 2000 | mse 0.0654 | cosLoss 0.8732 | cos 0.1268 | total 0.0939
# [EP 058] train_total=0.094058 | val_total=0.093555 | train_cos=0.874150 | val_cos=0.874208
# ep 59 step 2050 | mse 0.0660 | cosLoss 0.8813 | cos 0.1187 | total 0.0947
# [EP 059] train_total=0.094283 | val_total=0.095410 | train_cos=0.877706 | val_cos=0.883106
# [EP 060] train_total=0.094484 | val_total=0.093978 | train_cos=0.877057 | val_cos=0.875531
# ep 61 step 2100 | mse 0.0824 | cosLoss 0.8775 | cos 0.1225 | total 0.0960
# [EP 061] train_total=0.094137 | val_total=0.095146 | train_cos=0.877322 | val_cos=0.879120
# ep 62 step 2150 | mse 0.0829 | cosLoss 0.8771 | cos 0.1229 | total 0.0960
# [EP 062] train_total=0.094093 | val_total=0.094165 | train_cos=0.875007 | val_cos=0.876589
# ep 63 step 2200 | mse 0.0545 | cosLoss 0.8719 | cos 0.1281 | total 0.0926
# [EP 063] train_total=0.093501 | val_total=0.093719 | train_cos=0.872717 | val_cos=0.872815
# [EP 064] train_total=0.094081 | val_total=0.094351 | train_cos=0.873541 | val_cos=0.872781
# ep 65 step 2250 | mse 0.0573 | cosLoss 0.8721 | cos 0.1279 | total 0.0929
# [EP 065] train_total=0.093610 | val_total=0.093538 | train_cos=0.872077 | val_cos=0.872047
# ep 66 step 2300 | mse 0.0611 | cosLoss 0.8740 | cos 0.1260 | total 0.0935
# [EP 066] train_total=0.094133 | val_total=0.092969 | train_cos=0.873744 | val_cos=0.873894
# [EP 067] train_total=0.093744 | val_total=0.093801 | train_cos=0.872856 | val_cos=0.872598
# ep 68 step 2350 | mse 0.0650 | cosLoss 0.8724 | cos 0.1276 | total 0.0937
# [EP 068] train_total=0.093871 | val_total=0.093427 | train_cos=0.873221 | val_cos=0.872265
# ep 69 step 2400 | mse 0.0564 | cosLoss 0.8734 | cos 0.1266 | total 0.0930
# [EP 069] train_total=0.094388 | val_total=0.094187 | train_cos=0.873651 | val_cos=0.875189
# [EP 070] train_total=0.094114 | val_total=0.094328 | train_cos=0.873826 | val_cos=0.873019
# ep 71 step 2450 | mse 0.0682 | cosLoss 0.8726 | cos 0.1274 | total 0.0941
# [EP 071] train_total=0.094264 | val_total=0.093998 | train_cos=0.873557 | val_cos=0.875537
# ep 72 step 2500 | mse 0.0591 | cosLoss 0.8814 | cos 0.1186 | total 0.0940
# [EP 072] train_total=0.094114 | val_total=0.094472 | train_cos=0.876494 | val_cos=0.872893
# ep 73 step 2550 | mse 0.0621 | cosLoss 0.8730 | cos 0.1270 | total 0.0935
# [EP 073] train_total=0.094122 | val_total=0.094111 | train_cos=0.873234 | val_cos=0.873257
# [EP 074] train_total=0.093729 | val_total=0.093874 | train_cos=0.873845 | val_cos=0.873868
# ep 75 step 2600 | mse 0.0980 | cosLoss 0.8752 | cos 0.1248 | total 0.0973
# [EP 075] train_total=0.093914 | val_total=0.093800 | train_cos=0.872318 | val_cos=0.872286
# ep 76 step 2650 | mse 0.0825 | cosLoss 0.8733 | cos 0.1267 | total 0.0956
# [EP 076] train_total=0.093984 | val_total=0.093830 | train_cos=0.873045 | val_cos=0.873704
# [EP 077] train_total=0.093742 | val_total=0.093549 | train_cos=0.872998 | val_cos=0.872044
# ep 78 step 2700 | mse 0.0599 | cosLoss 0.8719 | cos 0.1281 | total 0.0932
# [EP 078] train_total=0.094118 | val_total=0.094184 | train_cos=0.872841 | val_cos=0.872494
# ep 79 step 2750 | mse 0.0650 | cosLoss 0.8718 | cos 0.1282 | total 0.0937
# [EP 079] train_total=0.093582 | val_total=0.093443 | train_cos=0.871955 | val_cos=0.871455
# [EP 080] train_total=0.093768 | val_total=0.094388 | train_cos=0.872535 | val_cos=0.873900
# ep 81 step 2800 | mse 0.0516 | cosLoss 0.8715 | cos 0.1285 | total 0.0923
# [EP 081] train_total=0.094420 | val_total=0.095197 | train_cos=0.876807 | val_cos=0.876548
# ep 82 step 2850 | mse 0.0661 | cosLoss 0.8730 | cos 0.1270 | total 0.0939
# [EP 082] train_total=0.094065 | val_total=0.094305 | train_cos=0.874052 | val_cos=0.872232
# ep 83 step 2900 | mse 0.0585 | cosLoss 0.8725 | cos 0.1275 | total 0.0931
# [EP 083] train_total=0.093733 | val_total=0.093901 | train_cos=0.872024 | val_cos=0.873085
# [EP 084] train_total=0.094316 | val_total=0.093414 | train_cos=0.876187 | val_cos=0.874746
# ep 85 step 2950 | mse 0.0644 | cosLoss 0.8760 | cos 0.1240 | total 0.0940
# [EP 085] train_total=0.094403 | val_total=0.095048 | train_cos=0.876220 | val_cos=0.879901
# ep 86 step 3000 | mse 0.0671 | cosLoss 0.8735 | cos 0.1265 | total 0.0941
# [EP 086] train_total=0.094310 | val_total=0.095537 | train_cos=0.878824 | val_cos=0.887821
# [EP 087] train_total=0.094076 | val_total=0.093421 | train_cos=0.874937 | val_cos=0.871624
# ep 88 step 3050 | mse 0.0713 | cosLoss 0.8722 | cos 0.1278 | total 0.0944
# [EP 088] train_total=0.094064 | val_total=0.092921 | train_cos=0.872597 | val_cos=0.870943
# ep 89 step 3100 | mse 0.0594 | cosLoss 0.8703 | cos 0.1297 | total 0.0930
# [EP 089] train_total=0.093657 | val_total=0.093350 | train_cos=0.871818 | val_cos=0.871330
# [EP 090] train_total=0.093851 | val_total=0.093316 | train_cos=0.871605 | val_cos=0.871495
# ep 91 step 3150 | mse 0.0715 | cosLoss 0.8711 | cos 0.1289 | total 0.0943
# [EP 091] train_total=0.093380 | val_total=0.094364 | train_cos=0.871898 | val_cos=0.872388
# ep 92 step 3200 | mse 0.0694 | cosLoss 0.8721 | cos 0.1279 | total 0.0941
# [EP 092] train_total=0.094021 | val_total=0.094418 | train_cos=0.872202 | val_cos=0.872579
# ep 93 step 3250 | mse 0.0596 | cosLoss 0.8744 | cos 0.1256 | total 0.0934
# [EP 093] train_total=0.093656 | val_total=0.093955 | train_cos=0.871856 | val_cos=0.872083
# [EP 094] train_total=0.093773 | val_total=0.092651 | train_cos=0.872156 | val_cos=0.871319
# ep 95 step 3300 | mse 0.0621 | cosLoss 0.8735 | cos 0.1265 | total 0.0936
# [EP 095] train_total=0.093733 | val_total=0.093357 | train_cos=0.872997 | val_cos=0.872402
# ep 96 step 3350 | mse 0.0577 | cosLoss 0.8733 | cos 0.1267 | total 0.0931
# [EP 096] train_total=0.093976 | val_total=0.094067 | train_cos=0.874996 | val_cos=0.879516
# [EP 097] train_total=0.093842 | val_total=0.094135 | train_cos=0.874318 | val_cos=0.875331
# ep 98 step 3400 | mse 0.0697 | cosLoss 0.8740 | cos 0.1260 | total 0.0944
# [EP 098] train_total=0.093698 | val_total=0.093838 | train_cos=0.873166 | val_cos=0.871756
# ep 99 step 3450 | mse 0.0673 | cosLoss 0.8708 | cos 0.1292 | total 0.0938
# [EP 099] train_total=0.093440 | val_total=0.093238 | train_cos=0.871405 | val_cos=0.870750
# [EP 100] train_total=0.093522 | val_total=0.093788 | train_cos=0.870904 | val_cos=0.871330
# ep 101 step 3500 | mse 0.0593 | cosLoss 0.8711 | cos 0.1289 | total 0.0930
# [EP 101] train_total=0.093619 | val_total=0.094482 | train_cos=0.872501 | val_cos=0.873787
# ep 102 step 3550 | mse 0.0717 | cosLoss 0.8738 | cos 0.1262 | total 0.0945
# [EP 102] train_total=0.093749 | val_total=0.093521 | train_cos=0.872762 | val_cos=0.871339
# ep 103 step 3600 | mse 0.0604 | cosLoss 0.8720 | cos 0.1280 | total 0.0932
# [EP 103] train_total=0.093890 | val_total=0.093604 | train_cos=0.871825 | val_cos=0.874311
# [EP 104] train_total=0.093832 | val_total=0.094486 | train_cos=0.873704 | val_cos=0.873181
# ep 105 step 3650 | mse 0.0755 | cosLoss 0.8746 | cos 0.1254 | total 0.0950
# [EP 105] train_total=0.093587 | val_total=0.093325 | train_cos=0.871714 | val_cos=0.870804
# ep 106 step 3700 | mse 0.0626 | cosLoss 0.8707 | cos 0.1293 | total 0.0933
# [EP 106] train_total=0.093267 | val_total=0.094478 | train_cos=0.870745 | val_cos=0.872538
# [EP 107] train_total=0.093870 | val_total=0.093862 | train_cos=0.872267 | val_cos=0.875143
# ep 108 step 3750 | mse 0.0620 | cosLoss 0.8730 | cos 0.1270 | total 0.0935
# [EP 108] train_total=0.093901 | val_total=0.094073 | train_cos=0.873016 | val_cos=0.871595
# ep 109 step 3800 | mse 0.0675 | cosLoss 0.8716 | cos 0.1284 | total 0.0939
# [EP 109] train_total=0.093733 | val_total=0.093128 | train_cos=0.871174 | val_cos=0.870620
# [EP 110] train_total=0.093668 | val_total=0.093084 | train_cos=0.871034 | val_cos=0.870613
# ep 111 step 3850 | mse 0.0765 | cosLoss 0.8722 | cos 0.1278 | total 0.0949
# [EP 111] train_total=0.093655 | val_total=0.093926 | train_cos=0.871827 | val_cos=0.870974
# ep 112 step 3900 | mse 0.0555 | cosLoss 0.8695 | cos 0.1305 | total 0.0925
# [EP 112] train_total=0.093368 | val_total=0.093182 | train_cos=0.871214 | val_cos=0.870862
# ep 113 step 3950 | mse 0.0586 | cosLoss 0.8734 | cos 0.1266 | total 0.0932
# [EP 113] train_total=0.094137 | val_total=0.094424 | train_cos=0.875741 | val_cos=0.876200
# [EP 114] train_total=0.094180 | val_total=0.093548 | train_cos=0.873794 | val_cos=0.873532
# ep 115 step 4000 | mse 0.0708 | cosLoss 0.8782 | cos 0.1218 | total 0.0949
# [EP 115] train_total=0.093992 | val_total=0.093537 | train_cos=0.874561 | val_cos=0.871995
# ep 116 step 4050 | mse 0.0665 | cosLoss 0.8759 | cos 0.1241 | total 0.0942
# [EP 116] train_total=0.093688 | val_total=0.094197 | train_cos=0.874154 | val_cos=0.881113
# [EP 117] train_total=0.094291 | val_total=0.092847 | train_cos=0.876507 | val_cos=0.872788
# ep 118 step 4100 | mse 0.0593 | cosLoss 0.8775 | cos 0.1225 | total 0.0937
# [EP 118] train_total=0.093848 | val_total=0.094373 | train_cos=0.877556 | val_cos=0.876634
# ep 119 step 4150 | mse 0.0558 | cosLoss 0.8815 | cos 0.1185 | total 0.0937
# [EP 119] train_total=0.094355 | val_total=0.094031 | train_cos=0.878618 | val_cos=0.874375
# [EP 120] train_total=0.093656 | val_total=0.093294 | train_cos=0.871327 | val_cos=0.870725
# ep 121 step 4200 | mse 0.0455 | cosLoss 0.8686 | cos 0.1314 | total 0.0914
# [EP 121] train_total=0.093210 | val_total=0.093948 | train_cos=0.870430 | val_cos=0.871255
# ep 122 step 4250 | mse 0.0575 | cosLoss 0.8697 | cos 0.1303 | total 0.0927
# [EP 122] train_total=0.093908 | val_total=0.093432 | train_cos=0.871576 | val_cos=0.870851
# ep 123 step 4300 | mse 0.0564 | cosLoss 0.8692 | cos 0.1308 | total 0.0926
# [EP 123] train_total=0.093323 | val_total=0.093472 | train_cos=0.870573 | val_cos=0.870417
# [EP 124] train_total=0.093475 | val_total=0.093081 | train_cos=0.870445 | val_cos=0.870053
# ep 125 step 4350 | mse 0.0587 | cosLoss 0.8695 | cos 0.1305 | total 0.0928
# [EP 125] train_total=0.093493 | val_total=0.092658 | train_cos=0.870561 | val_cos=0.869853
# ep 126 step 4400 | mse 0.0552 | cosLoss 0.8695 | cos 0.1305 | total 0.0925
# [EP 126] train_total=0.093355 | val_total=0.094143 | train_cos=0.870465 | val_cos=0.871416
# [EP 127] train_total=0.093650 | val_total=0.093604 | train_cos=0.871526 | val_cos=0.870877
# ep 128 step 4450 | mse 0.0687 | cosLoss 0.8708 | cos 0.1292 | total 0.0940
# [EP 128] train_total=0.093769 | val_total=0.093293 | train_cos=0.871017 | val_cos=0.870085
# ep 129 step 4500 | mse 0.0857 | cosLoss 0.8728 | cos 0.1272 | total 0.0959
# [EP 129] train_total=0.093065 | val_total=0.093577 | train_cos=0.870109 | val_cos=0.870596
# [EP 130] train_total=0.093657 | val_total=0.093710 | train_cos=0.871156 | val_cos=0.870881
# ep 131 step 4550 | mse 0.0471 | cosLoss 0.8694 | cos 0.1306 | total 0.0916
# [EP 131] train_total=0.093519 | val_total=0.092174 | train_cos=0.871276 | val_cos=0.869436
# ep 132 step 4600 | mse 0.0516 | cosLoss 0.8690 | cos 0.1310 | total 0.0921
# [EP 132] train_total=0.093451 | val_total=0.093211 | train_cos=0.870909 | val_cos=0.870094
# ep 133 step 4650 | mse 0.0860 | cosLoss 0.8734 | cos 0.1266 | total 0.0959
# [EP 133] train_total=0.093418 | val_total=0.093196 | train_cos=0.870643 | val_cos=0.874495
# [EP 134] train_total=0.093438 | val_total=0.093818 | train_cos=0.871935 | val_cos=0.871813
# ep 135 step 4700 | mse 0.0677 | cosLoss 0.8706 | cos 0.1294 | total 0.0938
# [EP 135] train_total=0.093296 | val_total=0.093338 | train_cos=0.870323 | val_cos=0.870086
# ep 136 step 4750 | mse 0.0702 | cosLoss 0.8719 | cos 0.1281 | total 0.0942
# [EP 136] train_total=0.093545 | val_total=0.093352 | train_cos=0.871237 | val_cos=0.876873
# [EP 137] train_total=0.093839 | val_total=0.094860 | train_cos=0.873123 | val_cos=0.875747
# ep 138 step 4800 | mse 0.0555 | cosLoss 0.8723 | cos 0.1277 | total 0.0928
# [EP 138] train_total=0.093773 | val_total=0.094470 | train_cos=0.872467 | val_cos=0.872431
# ep 139 step 4850 | mse 0.0448 | cosLoss 0.8683 | cos 0.1317 | total 0.0913
# [EP 139] train_total=0.093183 | val_total=0.093980 | train_cos=0.870348 | val_cos=0.870980
# [EP 140] train_total=0.093225 | val_total=0.093470 | train_cos=0.870067 | val_cos=0.869963
# ep 141 step 4900 | mse 0.0875 | cosLoss 0.8728 | cos 0.1272 | total 0.0960
# [EP 141] train_total=0.093777 | val_total=0.093285 | train_cos=0.870511 | val_cos=0.870266
# ep 142 step 4950 | mse 0.0626 | cosLoss 0.8700 | cos 0.1300 | total 0.0933
# [EP 142] train_total=0.093469 | val_total=0.093951 | train_cos=0.870903 | val_cos=0.873179
# ep 143 step 5000 | mse 0.0658 | cosLoss 0.8713 | cos 0.1287 | total 0.0937
# [EP 143] train_total=0.094179 | val_total=0.093801 | train_cos=0.875129 | val_cos=0.873365
# [EP 144] train_total=0.093342 | val_total=0.092926 | train_cos=0.871257 | val_cos=0.870369
# ep 145 step 5050 | mse 0.0589 | cosLoss 0.8712 | cos 0.1288 | total 0.0930
# [EP 145] train_total=0.093511 | val_total=0.093098 | train_cos=0.870321 | val_cos=0.870196
# ep 146 step 5100 | mse 0.0604 | cosLoss 0.8703 | cos 0.1297 | total 0.0931
# [EP 146] train_total=0.093360 | val_total=0.092736 | train_cos=0.870186 | val_cos=0.869572
# [EP 147] train_total=0.093133 | val_total=0.094334 | train_cos=0.870001 | val_cos=0.871658
# ep 148 step 5150 | mse 0.0657 | cosLoss 0.8702 | cos 0.1298 | total 0.0936
# [EP 148] train_total=0.093437 | val_total=0.094038 | train_cos=0.870488 | val_cos=0.871449
# ep 149 step 5200 | mse 0.0537 | cosLoss 0.8708 | cos 0.1292 | total 0.0924
# [EP 149] train_total=0.093967 | val_total=0.093722 | train_cos=0.873920 | val_cos=0.873486
# [EP 150] train_total=0.093853 | val_total=0.093385 | train_cos=0.873529 | val_cos=0.874337
# ep 151 step 5250 | mse 0.0903 | cosLoss 0.8769 | cos 0.1231 | total 0.0967
# [EP 151] train_total=0.093306 | val_total=0.093171 | train_cos=0.871691 | val_cos=0.869833
# ep 152 step 5300 | mse 0.0642 | cosLoss 0.8696 | cos 0.1304 | total 0.0934
# [EP 152] train_total=0.093542 | val_total=0.093099 | train_cos=0.870242 | val_cos=0.869657
# ep 153 step 5350 | mse 0.0828 | cosLoss 0.8716 | cos 0.1284 | total 0.0954
# [EP 153] train_total=0.093513 | val_total=0.093470 | train_cos=0.870204 | val_cos=0.870332
# [EP 154] train_total=0.093548 | val_total=0.093431 | train_cos=0.871130 | val_cos=0.870711
# ep 155 step 5400 | mse 0.0727 | cosLoss 0.8716 | cos 0.1284 | total 0.0944
# [EP 155] train_total=0.093126 | val_total=0.093768 | train_cos=0.869811 | val_cos=0.870507
# ep 156 step 5450 | mse 0.0556 | cosLoss 0.8693 | cos 0.1307 | total 0.0925
# [EP 156] train_total=0.093572 | val_total=0.093988 | train_cos=0.870088 | val_cos=0.870712
# [EP 157] train_total=0.093595 | val_total=0.098554 | train_cos=0.874694 | val_cos=0.917647
# ep 158 step 5500 | mse 0.0832 | cosLoss 0.9348 | cos 0.0652 | total 0.1018
# [EP 158] train_total=0.095282 | val_total=0.094275 | train_cos=0.885391 | val_cos=0.871762
# ep 159 step 5550 | mse 0.0595 | cosLoss 0.8702 | cos 0.1298 | total 0.0930
# [EP 159] train_total=0.093553 | val_total=0.092697 | train_cos=0.871438 | val_cos=0.870547
# [EP 160] train_total=0.093616 | val_total=0.092961 | train_cos=0.870737 | val_cos=0.869362
# ep 161 step 5600 | mse 0.0615 | cosLoss 0.8692 | cos 0.1308 | total 0.0931
# [EP 161] train_total=0.093566 | val_total=0.095124 | train_cos=0.870639 | val_cos=0.873241
# ep 162 step 5650 | mse 0.0661 | cosLoss 0.8708 | cos 0.1292 | total 0.0937
# [EP 162] train_total=0.093500 | val_total=0.093353 | train_cos=0.870128 | val_cos=0.869973
# ep 163 step 5700 | mse 0.0660 | cosLoss 0.8721 | cos 0.1279 | total 0.0938
# [EP 163] train_total=0.093306 | val_total=0.091986 | train_cos=0.870399 | val_cos=0.869865
# [EP 164] train_total=0.093482 | val_total=0.093246 | train_cos=0.870459 | val_cos=0.869924
# ep 165 step 5750 | mse 0.0705 | cosLoss 0.8714 | cos 0.1286 | total 0.0942
# [EP 165] train_total=0.093457 | val_total=0.094040 | train_cos=0.870396 | val_cos=0.872710
# ep 166 step 5800 | mse 0.0646 | cosLoss 0.8700 | cos 0.1300 | total 0.0935
# [EP 166] train_total=0.093931 | val_total=0.093367 | train_cos=0.871084 | val_cos=0.870358
# [EP 167] train_total=0.093380 | val_total=0.093650 | train_cos=0.870365 | val_cos=0.871010
# ep 168 step 5850 | mse 0.0661 | cosLoss 0.8703 | cos 0.1297 | total 0.0936
# [EP 168] train_total=0.093540 | val_total=0.093311 | train_cos=0.870613 | val_cos=0.869709
# ep 169 step 5900 | mse 0.0850 | cosLoss 0.8727 | cos 0.1273 | total 0.0958
# [EP 169] train_total=0.093680 | val_total=0.093165 | train_cos=0.870471 | val_cos=0.871276
# [EP 170] train_total=0.093168 | val_total=0.093782 | train_cos=0.870172 | val_cos=0.871905
# ep 171 step 5950 | mse 0.0750 | cosLoss 0.8723 | cos 0.1277 | total 0.0947
# [EP 171] train_total=0.093352 | val_total=0.093466 | train_cos=0.870459 | val_cos=0.870118
# ep 172 step 6000 | mse 0.0656 | cosLoss 0.8707 | cos 0.1293 | total 0.0936
# [EP 172] train_total=0.093522 | val_total=0.093875 | train_cos=0.870703 | val_cos=0.871901
# ep 173 step 6050 | mse 0.0545 | cosLoss 0.8755 | cos 0.1245 | total 0.0930
# [EP 173] train_total=0.093980 | val_total=0.094218 | train_cos=0.876459 | val_cos=0.879751
# [EP 174] train_total=0.094144 | val_total=0.092999 | train_cos=0.877933 | val_cos=0.871119
# ep 175 step 6100 | mse 0.0695 | cosLoss 0.8881 | cos 0.1119 | total 0.0958
# [EP 175] train_total=0.093910 | val_total=0.093358 | train_cos=0.874329 | val_cos=0.870234
# ep 176 step 6150 | mse 0.0724 | cosLoss 0.8710 | cos 0.1290 | total 0.0943
# [EP 176] train_total=0.093268 | val_total=0.093231 | train_cos=0.869803 | val_cos=0.869345
# [EP 177] train_total=0.093424 | val_total=0.093806 | train_cos=0.869723 | val_cos=0.870239
# ep 178 step 6200 | mse 0.0859 | cosLoss 0.8721 | cos 0.1279 | total 0.0958
# [EP 178] train_total=0.093354 | val_total=0.092796 | train_cos=0.870162 | val_cos=0.869523
# ep 179 step 6250 | mse 0.0686 | cosLoss 0.8705 | cos 0.1295 | total 0.0939
# [EP 179] train_total=0.093523 | val_total=0.093935 | train_cos=0.870071 | val_cos=0.869829
# [EP 180] train_total=0.093364 | val_total=0.092499 | train_cos=0.869553 | val_cos=0.869029
# ep 181 step 6300 | mse 0.0574 | cosLoss 0.8684 | cos 0.1316 | total 0.0926
# [EP 181] train_total=0.093191 | val_total=0.092756 | train_cos=0.869477 | val_cos=0.869165
# ep 182 step 6350 | mse 0.0777 | cosLoss 0.8711 | cos 0.1289 | total 0.0949
# [EP 182] train_total=0.093516 | val_total=0.092824 | train_cos=0.869713 | val_cos=0.868839
# ep 183 step 6400 | mse 0.0658 | cosLoss 0.8691 | cos 0.1309 | total 0.0935
# [EP 183] train_total=0.093104 | val_total=0.093818 | train_cos=0.869376 | val_cos=0.870341
# [EP 184] train_total=0.093458 | val_total=0.094041 | train_cos=0.869629 | val_cos=0.870776
# ep 185 step 6450 | mse 0.0621 | cosLoss 0.8692 | cos 0.1308 | total 0.0931
# [EP 185] train_total=0.093292 | val_total=0.094873 | train_cos=0.870169 | val_cos=0.871581
# ep 186 step 6500 | mse 0.0615 | cosLoss 0.8687 | cos 0.1313 | total 0.0930
# [EP 186] train_total=0.093296 | val_total=0.093660 | train_cos=0.869569 | val_cos=0.869992
# [EP 187] train_total=0.093568 | val_total=0.092923 | train_cos=0.870604 | val_cos=0.869271
# ep 188 step 6550 | mse 0.0534 | cosLoss 0.8682 | cos 0.1318 | total 0.0922
# [EP 188] train_total=0.093378 | val_total=0.093395 | train_cos=0.870173 | val_cos=0.871147
# ep 189 step 6600 | mse 0.0667 | cosLoss 0.8694 | cos 0.1306 | total 0.0936
# [EP 189] train_total=0.093372 | val_total=0.093259 | train_cos=0.870455 | val_cos=0.869199
# [EP 190] train_total=0.093459 | val_total=0.092548 | train_cos=0.870410 | val_cos=0.869200
# ep 191 step 6650 | mse 0.0574 | cosLoss 0.8684 | cos 0.1316 | total 0.0926
# [EP 191] train_total=0.093545 | val_total=0.093369 | train_cos=0.871431 | val_cos=0.873878
# ep 192 step 6700 | mse 0.0665 | cosLoss 0.8738 | cos 0.1262 | total 0.0940
# [EP 192] train_total=0.093647 | val_total=0.094045 | train_cos=0.873757 | val_cos=0.871442
# ep 193 step 6750 | mse 0.0628 | cosLoss 0.8708 | cos 0.1292 | total 0.0934
# [EP 193] train_total=0.093099 | val_total=0.092778 | train_cos=0.869526 | val_cos=0.868983
# [EP 194] train_total=0.093219 | val_total=0.093808 | train_cos=0.869340 | val_cos=0.870271
# ep 195 step 6800 | mse 0.0616 | cosLoss 0.8698 | cos 0.1302 | total 0.0931
# [EP 195] train_total=0.093565 | val_total=0.093925 | train_cos=0.869732 | val_cos=0.870771
# ep 196 step 6850 | mse 0.0598 | cosLoss 0.8695 | cos 0.1305 | total 0.0929
# [EP 196] train_total=0.093361 | val_total=0.092436 | train_cos=0.870033 | val_cos=0.869287
# [EP 197] train_total=0.093411 | val_total=0.094031 | train_cos=0.869436 | val_cos=0.870554
# ep 198 step 6900 | mse 0.0532 | cosLoss 0.8690 | cos 0.1310 | total 0.0922
# [EP 198] train_total=0.093282 | val_total=0.093820 | train_cos=0.870356 | val_cos=0.870922
# ep 199 step 6950 | mse 0.0664 | cosLoss 0.8743 | cos 0.1257 | total 0.0941
# [EP 199] train_total=0.093375 | val_total=0.093520 | train_cos=0.870711 | val_cos=0.870425
# [EP 200] train_total=0.093677 | val_total=0.093591 | train_cos=0.870149 | val_cos=0.870386
# ep 201 step 7000 | mse 0.0552 | cosLoss 0.8685 | cos 0.1315 | total 0.0924
# [EP 201] train_total=0.093434 | val_total=0.093586 | train_cos=0.870221 | val_cos=0.872538
# ep 202 step 7050 | mse 0.0573 | cosLoss 0.8704 | cos 0.1296 | total 0.0928
# [EP 202] train_total=0.093302 | val_total=0.093484 | train_cos=0.870741 | val_cos=0.871102
# ep 203 step 7100 | mse 0.0684 | cosLoss 0.8710 | cos 0.1290 | total 0.0939
# [EP 203] train_total=0.093365 | val_total=0.093853 | train_cos=0.870022 | val_cos=0.870830
# [EP 204] train_total=0.092949 | val_total=0.092860 | train_cos=0.869698 | val_cos=0.870028
# ep 205 step 7150 | mse 0.0689 | cosLoss 0.8725 | cos 0.1275 | total 0.0941
# [EP 205] train_total=0.094159 | val_total=0.094248 | train_cos=0.876812 | val_cos=0.872741
# ep 206 step 7200 | mse 0.0749 | cosLoss 0.8772 | cos 0.1228 | total 0.0952
# [EP 206] train_total=0.093695 | val_total=0.093651 | train_cos=0.873818 | val_cos=0.871729
# [EP 207] train_total=0.093788 | val_total=0.093325 | train_cos=0.873483 | val_cos=0.870864
# ep 208 step 7250 | mse 0.0724 | cosLoss 0.8715 | cos 0.1285 | total 0.0944
# [EP 208] train_total=0.093230 | val_total=0.092067 | train_cos=0.869512 | val_cos=0.868475
# ep 209 step 7300 | mse 0.0578 | cosLoss 0.8684 | cos 0.1316 | total 0.0926
# [EP 209] train_total=0.093228 | val_total=0.093345 | train_cos=0.869174 | val_cos=0.868754
# [EP 210] train_total=0.093183 | val_total=0.093259 | train_cos=0.869119 | val_cos=0.869561
# ep 211 step 7350 | mse 0.0663 | cosLoss 0.8701 | cos 0.1299 | total 0.0936
# [EP 211] train_total=0.093574 | val_total=0.093393 | train_cos=0.870024 | val_cos=0.870318
# ep 212 step 7400 | mse 0.0721 | cosLoss 0.8734 | cos 0.1266 | total 0.0945
# [EP 212] train_total=0.093410 | val_total=0.093218 | train_cos=0.869937 | val_cos=0.869789
# ep 213 step 7450 | mse 0.0672 | cosLoss 0.8708 | cos 0.1292 | total 0.0938
# [EP 213] train_total=0.093441 | val_total=0.091835 | train_cos=0.869414 | val_cos=0.867665
# [EP 214] train_total=0.093049 | val_total=0.093604 | train_cos=0.869277 | val_cos=0.871937
# ep 215 step 7500 | mse 0.0760 | cosLoss 0.8721 | cos 0.1279 | total 0.0948
# [EP 215] train_total=0.093317 | val_total=0.093398 | train_cos=0.869913 | val_cos=0.870030
# ep 216 step 7550 | mse 0.0668 | cosLoss 0.8707 | cos 0.1293 | total 0.0937
# [EP 216] train_total=0.093135 | val_total=0.093104 | train_cos=0.869620 | val_cos=0.869811
# [EP 217] train_total=0.093423 | val_total=0.093728 | train_cos=0.869979 | val_cos=0.869526
# ep 218 step 7600 | mse 0.0555 | cosLoss 0.8680 | cos 0.1320 | total 0.0924
# [EP 218] train_total=0.092991 | val_total=0.093134 | train_cos=0.868816 | val_cos=0.869095
# ep 219 step 7650 | mse 0.0624 | cosLoss 0.8677 | cos 0.1323 | total 0.0930
# [EP 219] train_total=0.092964 | val_total=0.093436 | train_cos=0.869059 | val_cos=0.869411
# [EP 220] train_total=0.093630 | val_total=0.094028 | train_cos=0.875504 | val_cos=0.876467
# ep 221 step 7700 | mse 0.0600 | cosLoss 0.8760 | cos 0.1240 | total 0.0936
# [EP 221] train_total=0.094062 | val_total=0.093733 | train_cos=0.876810 | val_cos=0.871250
# ep 222 step 7750 | mse 0.0494 | cosLoss 0.8703 | cos 0.1297 | total 0.0920
# [EP 222] train_total=0.093475 | val_total=0.092990 | train_cos=0.871570 | val_cos=0.873900
# ep 223 step 7800 | mse 0.0604 | cosLoss 0.8703 | cos 0.1297 | total 0.0931
# [EP 223] train_total=0.093709 | val_total=0.093303 | train_cos=0.872050 | val_cos=0.869463
# [EP 224] train_total=0.093036 | val_total=0.093323 | train_cos=0.868985 | val_cos=0.869538
# ep 225 step 7850 | mse 0.0587 | cosLoss 0.8682 | cos 0.1318 | total 0.0927
# [EP 225] train_total=0.093276 | val_total=0.093011 | train_cos=0.869138 | val_cos=0.868900
# ep 226 step 7900 | mse 0.0553 | cosLoss 0.8673 | cos 0.1327 | total 0.0923
# [EP 226] train_total=0.093011 | val_total=0.093024 | train_cos=0.868848 | val_cos=0.868989
# [EP 227] train_total=0.093214 | val_total=0.093449 | train_cos=0.869100 | val_cos=0.870304
# ep 228 step 7950 | mse 0.0588 | cosLoss 0.8685 | cos 0.1315 | total 0.0927
# [EP 228] train_total=0.093689 | val_total=0.092543 | train_cos=0.870924 | val_cos=0.869035
# ep 229 step 8000 | mse 0.0488 | cosLoss 0.8694 | cos 0.1306 | total 0.0918
# [EP 229] train_total=0.093344 | val_total=0.093846 | train_cos=0.869633 | val_cos=0.869371
# [EP 230] train_total=0.093016 | val_total=0.093169 | train_cos=0.869195 | val_cos=0.870777
# ep 231 step 8050 | mse 0.0623 | cosLoss 0.8713 | cos 0.1287 | total 0.0934
# [EP 231] train_total=0.093447 | val_total=0.093069 | train_cos=0.870110 | val_cos=0.870392
# ep 232 step 8100 | mse 0.0630 | cosLoss 0.8698 | cos 0.1302 | total 0.0933
# [EP 232] train_total=0.093057 | val_total=0.093444 | train_cos=0.869273 | val_cos=0.869165
# ep 233 step 8150 | mse 0.0643 | cosLoss 0.8695 | cos 0.1305 | total 0.0934
# [EP 233] train_total=0.093044 | val_total=0.093348 | train_cos=0.868798 | val_cos=0.869478
# [EP 234] train_total=0.093012 | val_total=0.093405 | train_cos=0.868711 | val_cos=0.869019
# ep 235 step 8200 | mse 0.0437 | cosLoss 0.8670 | cos 0.1330 | total 0.0911
# [EP 235] train_total=0.093050 | val_total=0.093695 | train_cos=0.868825 | val_cos=0.869929
# ep 236 step 8250 | mse 0.0771 | cosLoss 0.8716 | cos 0.1284 | total 0.0949
# [EP 236] train_total=0.093008 | val_total=0.094648 | train_cos=0.870286 | val_cos=0.875677
# [EP 237] train_total=0.093701 | val_total=0.093399 | train_cos=0.876318 | val_cos=0.871406
# ep 238 step 8300 | mse 0.0643 | cosLoss 0.8720 | cos 0.1280 | total 0.0936
# [EP 238] train_total=0.093349 | val_total=0.093401 | train_cos=0.869797 | val_cos=0.869317
# ep 239 step 8350 | mse 0.0653 | cosLoss 0.8687 | cos 0.1313 | total 0.0934
# [EP 239] train_total=0.093049 | val_total=0.093043 | train_cos=0.868742 | val_cos=0.868734
# [EP 240] train_total=0.093164 | val_total=0.093424 | train_cos=0.868859 | val_cos=0.869028
# ep 241 step 8400 | mse 0.0560 | cosLoss 0.8682 | cos 0.1318 | total 0.0924
# [EP 241] train_total=0.093243 | val_total=0.093144 | train_cos=0.869082 | val_cos=0.868945
# ep 242 step 8450 | mse 0.0553 | cosLoss 0.8676 | cos 0.1324 | total 0.0923
# [EP 242] train_total=0.093197 | val_total=0.092940 | train_cos=0.868752 | val_cos=0.868370
# ep 243 step 8500 | mse 0.0585 | cosLoss 0.8680 | cos 0.1320 | total 0.0926
# [EP 243] train_total=0.093109 | val_total=0.092980 | train_cos=0.868814 | val_cos=0.869297
# [EP 244] train_total=0.093347 | val_total=0.093047 | train_cos=0.870770 | val_cos=0.869132
# ep 245 step 8550 | mse 0.0762 | cosLoss 0.8715 | cos 0.1285 | total 0.0948
# [EP 245] train_total=0.093162 | val_total=0.092805 | train_cos=0.869043 | val_cos=0.868234
# ep 246 step 8600 | mse 0.0658 | cosLoss 0.8694 | cos 0.1306 | total 0.0935
# [EP 246] train_total=0.093029 | val_total=0.092899 | train_cos=0.868574 | val_cos=0.868751
# [EP 247] train_total=0.093400 | val_total=0.092943 | train_cos=0.870087 | val_cos=0.868479
# ep 248 step 8650 | mse 0.0497 | cosLoss 0.8677 | cos 0.1323 | total 0.0917
# [EP 248] train_total=0.093566 | val_total=0.092457 | train_cos=0.870121 | val_cos=0.869009
# ep 249 step 8700 | mse 0.0645 | cosLoss 0.8699 | cos 0.1301 | total 0.0934
# [EP 249] train_total=0.093347 | val_total=0.093462 | train_cos=0.869544 | val_cos=0.869332
# [EP 250] train_total=0.093241 | val_total=0.093878 | train_cos=0.869243 | val_cos=0.869306
# ep 251 step 8750 | mse 0.0738 | cosLoss 0.8705 | cos 0.1295 | total 0.0944
# [EP 251] train_total=0.092979 | val_total=0.092879 | train_cos=0.868603 | val_cos=0.869243
# ep 252 step 8800 | mse 0.0608 | cosLoss 0.8691 | cos 0.1309 | total 0.0930
# [EP 252] train_total=0.093232 | val_total=0.094009 | train_cos=0.869908 | val_cos=0.871042
# ep 253 step 8850 | mse 0.0767 | cosLoss 0.8712 | cos 0.1288 | total 0.0948
# [EP 253] train_total=0.093213 | val_total=0.093310 | train_cos=0.870363 | val_cos=0.870591
# [EP 254] train_total=0.093210 | val_total=0.093145 | train_cos=0.870940 | val_cos=0.869434
# ep 255 step 8900 | mse 0.0702 | cosLoss 0.8699 | cos 0.1301 | total 0.0940
# [EP 255] train_total=0.093271 | val_total=0.092781 | train_cos=0.869163 | val_cos=0.869389
# ep 256 step 8950 | mse 0.0508 | cosLoss 0.8675 | cos 0.1325 | total 0.0918
# [EP 256] train_total=0.093225 | val_total=0.092510 | train_cos=0.869387 | val_cos=0.869993
# [EP 257] train_total=0.093319 | val_total=0.092428 | train_cos=0.869685 | val_cos=0.867985
# ep 258 step 9000 | mse 0.0598 | cosLoss 0.8687 | cos 0.1313 | total 0.0928
# [EP 258] train_total=0.093108 | val_total=0.092573 | train_cos=0.868762 | val_cos=0.868162
# ep 259 step 9050 | mse 0.0461 | cosLoss 0.8665 | cos 0.1335 | total 0.0913
# [EP 259] train_total=0.093141 | val_total=0.092908 | train_cos=0.868523 | val_cos=0.868959
# [EP 260] train_total=0.093172 | val_total=0.093776 | train_cos=0.869176 | val_cos=0.869407
# ep 261 step 9100 | mse 0.0550 | cosLoss 0.8679 | cos 0.1321 | total 0.0923
# [EP 261] train_total=0.093246 | val_total=0.092572 | train_cos=0.869485 | val_cos=0.868513
# ep 262 step 9150 | mse 0.0508 | cosLoss 0.8675 | cos 0.1325 | total 0.0918
# [EP 262] train_total=0.093007 | val_total=0.093621 | train_cos=0.868667 | val_cos=0.869572
# ep 263 step 9200 | mse 0.0705 | cosLoss 0.8734 | cos 0.1266 | total 0.0944
# [EP 263] train_total=0.093421 | val_total=0.093752 | train_cos=0.872367 | val_cos=0.875965
# [EP 264] train_total=0.093502 | val_total=0.092995 | train_cos=0.871105 | val_cos=0.868465
# ep 265 step 9250 | mse 0.0563 | cosLoss 0.8673 | cos 0.1327 | total 0.0924
# [EP 265] train_total=0.093008 | val_total=0.092735 | train_cos=0.868472 | val_cos=0.867880
# ep 266 step 9300 | mse 0.0776 | cosLoss 0.8697 | cos 0.1303 | total 0.0947
# [EP 266] train_total=0.093061 | val_total=0.093435 | train_cos=0.868529 | val_cos=0.868736
# [EP 267] train_total=0.093019 | val_total=0.092844 | train_cos=0.868271 | val_cos=0.868127
# ep 268 step 9350 | mse 0.0657 | cosLoss 0.8692 | cos 0.1308 | total 0.0935
# [EP 268] train_total=0.092866 | val_total=0.093406 | train_cos=0.868301 | val_cos=0.869457
# ep 269 step 9400 | mse 0.0589 | cosLoss 0.8690 | cos 0.1310 | total 0.0928
# [EP 269] train_total=0.093476 | val_total=0.093847 | train_cos=0.871620 | val_cos=0.878373
# [EP 270] train_total=0.093244 | val_total=0.094221 | train_cos=0.871738 | val_cos=0.874247
# ep 271 step 9450 | mse 0.0794 | cosLoss 0.8749 | cos 0.1251 | total 0.0954
# [EP 271] train_total=0.093454 | val_total=0.092727 | train_cos=0.870246 | val_cos=0.869121
# ep 272 step 9500 | mse 0.0818 | cosLoss 0.8709 | cos 0.1291 | total 0.0953
# [EP 272] train_total=0.093048 | val_total=0.092660 | train_cos=0.868733 | val_cos=0.868537
# ep 273 step 9550 | mse 0.0559 | cosLoss 0.8673 | cos 0.1327 | total 0.0923
# [EP 273] train_total=0.092670 | val_total=0.092824 | train_cos=0.867871 | val_cos=0.868159
# [EP 274] train_total=0.093199 | val_total=0.093596 | train_cos=0.868291 | val_cos=0.868889
# ep 275 step 9600 | mse 0.0461 | cosLoss 0.8681 | cos 0.1319 | total 0.0914
# [EP 275] train_total=0.092762 | val_total=0.092587 | train_cos=0.868702 | val_cos=0.869521
# ep 276 step 9650 | mse 0.0659 | cosLoss 0.8680 | cos 0.1320 | total 0.0934
# [EP 276] train_total=0.093431 | val_total=0.092342 | train_cos=0.869436 | val_cos=0.867744
# [EP 277] train_total=0.093063 | val_total=0.092814 | train_cos=0.868679 | val_cos=0.868637
# ep 278 step 9700 | mse 0.0714 | cosLoss 0.8688 | cos 0.1312 | total 0.0940
# [EP 278] train_total=0.092742 | val_total=0.092010 | train_cos=0.867841 | val_cos=0.867069
# ep 279 step 9750 | mse 0.0694 | cosLoss 0.8688 | cos 0.1312 | total 0.0938
# [EP 279] train_total=0.092677 | val_total=0.092459 | train_cos=0.867948 | val_cos=0.868170
# [EP 280] train_total=0.093650 | val_total=0.093293 | train_cos=0.871253 | val_cos=0.869039
# ep 281 step 9800 | mse 0.0578 | cosLoss 0.8677 | cos 0.1323 | total 0.0925
# [EP 281] train_total=0.093647 | val_total=0.093978 | train_cos=0.871676 | val_cos=0.877134
# ep 282 step 9850 | mse 0.0421 | cosLoss 0.8695 | cos 0.1305 | total 0.0912
# [EP 282] train_total=0.093535 | val_total=0.093578 | train_cos=0.872755 | val_cos=0.870824
# ep 283 step 9900 | mse 0.0685 | cosLoss 0.8692 | cos 0.1308 | total 0.0938
# [EP 283] train_total=0.093061 | val_total=0.092794 | train_cos=0.868711 | val_cos=0.868404
# [EP 284] train_total=0.092832 | val_total=0.092822 | train_cos=0.867950 | val_cos=0.868005
# ep 285 step 9950 | mse 0.0545 | cosLoss 0.8675 | cos 0.1325 | total 0.0922
# [EP 285] train_total=0.092882 | val_total=0.092951 | train_cos=0.867890 | val_cos=0.868000
# ep 286 step 10000 | mse 0.0668 | cosLoss 0.8689 | cos 0.1311 | total 0.0936
# [EP 286] train_total=0.093249 | val_total=0.092580 | train_cos=0.868287 | val_cos=0.868000
# [EP 287] train_total=0.092761 | val_total=0.093308 | train_cos=0.867751 | val_cos=0.868561
# ep 288 step 10050 | mse 0.0537 | cosLoss 0.8676 | cos 0.1324 | total 0.0921
# [EP 288] train_total=0.093192 | val_total=0.093245 | train_cos=0.868300 | val_cos=0.868991
# ep 289 step 10100 | mse 0.0634 | cosLoss 0.8684 | cos 0.1316 | total 0.0932
# [EP 289] train_total=0.093096 | val_total=0.093773 | train_cos=0.868428 | val_cos=0.869245
# [EP 290] train_total=0.092960 | val_total=0.093416 | train_cos=0.868871 | val_cos=0.869446
# ep 291 step 10150 | mse 0.0562 | cosLoss 0.8674 | cos 0.1326 | total 0.0924
# [EP 291] train_total=0.093226 | val_total=0.093096 | train_cos=0.870639 | val_cos=0.870531
# ep 292 step 10200 | mse 0.0686 | cosLoss 0.8694 | cos 0.1306 | total 0.0938
# [EP 292] train_total=0.093106 | val_total=0.092703 | train_cos=0.868613 | val_cos=0.868371
# ep 293 step 10250 | mse 0.0603 | cosLoss 0.8667 | cos 0.1333 | total 0.0927
# [EP 293] train_total=0.092603 | val_total=0.093468 | train_cos=0.867626 | val_cos=0.868729
# [EP 294] train_total=0.093119 | val_total=0.092331 | train_cos=0.868051 | val_cos=0.867190
# ep 295 step 10300 | mse 0.0678 | cosLoss 0.8681 | cos 0.1319 | total 0.0936
# [EP 295] train_total=0.092904 | val_total=0.093146 | train_cos=0.867992 | val_cos=0.868448
# ep 296 step 10350 | mse 0.0658 | cosLoss 0.8693 | cos 0.1307 | total 0.0935
# [EP 296] train_total=0.092977 | val_total=0.094103 | train_cos=0.867956 | val_cos=0.869090
# [EP 297] train_total=0.093116 | val_total=0.092406 | train_cos=0.867986 | val_cos=0.867588
# ep 298 step 10400 | mse 0.0559 | cosLoss 0.8668 | cos 0.1332 | total 0.0923
# [EP 298] train_total=0.093024 | val_total=0.093250 | train_cos=0.868130 | val_cos=0.869073
# ep 299 step 10450 | mse 0.0613 | cosLoss 0.8711 | cos 0.1289 | total 0.0932
# [EP 299] train_total=0.093045 | val_total=0.093714 | train_cos=0.869513 | val_cos=0.868769
# [EP 300] train_total=0.092521 | val_total=0.093154 | train_cos=0.867542 | val_cos=0.868169
#
# TRAINED FOR: 300 epochs
# TRAINING TIME: 6.48 minutes (388.6 seconds)
# Last ckpt dir: /data/silvija/diffusion_results/diffusion_ckpts

# %%
dl_eval = DataLoader(ds, batch_size=256, shuffle=False, num_workers=4, pin_memory=True)

gen_list = []
ctx_list = []

start_time = time.time()
denoiser.eval()
with torch.no_grad():
    for xml_proj, _zr_feat in dl_eval:
        xml_proj = xml_proj.to(device, non_blocking=True)

        xml_ctx = clip.xml_projection(clip.xml_encoder(xml_proj))
        xml_ctx = F.normalize(xml_ctx, dim=-1)  # [B,128]

        x_gen = diffusion.sample(context=xml_ctx, shape=(xml_ctx.shape[0], 128))

        gen_list.append(x_gen.cpu())
        ctx_list.append(xml_ctx.cpu())

elapsed_time = time.time() - start_time
print(f"Sampling elapsed time: {elapsed_time:.3f} seconds")

zr_gen = torch.cat(gen_list, dim=0).numpy().astype(np.float32)
xml_ctx_used = torch.cat(ctx_list, dim=0).numpy().astype(np.float32)

zr_gen_path = os.path.join(OUT_DIR, "zr_features_gen.npy")
xml_ctx_path = os.path.join(OUT_DIR, "xml_ctx_used.npy")

np.save(zr_gen_path, zr_gen)
np.save(xml_ctx_path, xml_ctx_used)

print("Saved generated:", zr_gen_path)
print("Saved ctx used :", xml_ctx_path)
print("zr_gen:", zr_gen.shape, "xml_ctx_used:", xml_ctx_used.shape)
# Out:
# Sampling elapsed time: 21.831 seconds
# Saved generated: /data/silvija/diffusion_results/zr_features_gen.npy
# Saved ctx used : /data/silvija/diffusion_results/xml_ctx_used.npy
# zr_gen: (10000, 128) xml_ctx_used: (10000, 128)

# %%
zr_gen_t = torch.from_numpy(zr_gen).to(device)
xmlp_t   = torch.from_numpy(xml_ctx_used).to(device)

with torch.no_grad():
    zr_enc = F.normalize(clip.zr_encoder(zr_gen_t), dim=-1)  # [N,128]
    xmlp_t = F.normalize(xmlp_t, dim=-1)                    # [N,128]
    cos_diag = F.cosine_similarity(zr_enc, xmlp_t, dim=-1)

print("diag cosine mean:", cos_diag.mean().item())
print("diag cosine std :", cos_diag.std(unbiased=False).item())
print("diag cosine min/max:", cos_diag.min().item(), cos_diag.max().item())
# Out:
# diag cosine mean: 0.06204404681921005
# diag cosine std : 0.007952597923576832
# diag cosine min/max: 0.022848740220069885 0.08399064093828201

# %%
import matplotlib.pyplot as plt
epochs_axis = np.arange(1, len(train_total_losses) + 1)

plt.figure(figsize=(10, 5))
plt.plot(epochs_axis, train_total_losses, linewidth=4, label="Train Loss")
plt.plot(epochs_axis, val_total_losses, linewidth=4, label="Val Loss")
plt.yscale("log")
plt.xlabel("Epoch", fontsize=26, fontweight="bold")
plt.ylabel("Total Loss (log)", fontsize=26, fontweight="bold")
plt.title("Training loss", fontsize=34, fontweight="bold")
plt.grid(True, which="both", linestyle="--", alpha=0.35)
plt.legend(fontsize=24, framealpha=0.9)
plt.tight_layout()
plt.savefig("diffusion_losses.png")
plt.show()

# %%
OUT_DIR = "/data/silvija/diffusion_results"

# Ground-truth raw zR
zr_path = os.path.join(OUT_DIR, "zr_features.npy")            # [N,128]
zr = np.load(zr_path).astype(np.float32)

# Generated zR (your saved output)
zr_gen_path = os.path.join(OUT_DIR, "zr_features_gen.npy")    # [N,128]
zr_gen = np.load(zr_gen_path).astype(np.float32)

# Context used (optional, for cosine checks)
xml_ctx_path = os.path.join(OUT_DIR, "xml_ctx_used.npy")      # [N,128]
xml_ctx_used = np.load(xml_ctx_path).astype(np.float32)

print("zr:", zr.shape, "zr_gen:", zr_gen.shape, "xml_ctx_used:", xml_ctx_used.shape)
# Out:
# zr: (10000, 128) zr_gen: (10000, 128) xml_ctx_used: (10000, 128)

# %%
plt.figure(figsize=(10, 5))
plt.hist(zr.reshape(-1), bins=200, alpha=0.5, label="z_R (GT)", density=True)
plt.hist(zr_gen.reshape(-1), bins=200, alpha=0.5, label="z_R_generated", density=True)
plt.title("z_R vs z_R_generated", fontsize=22, fontweight="bold")
plt.xlabel("Value", fontsize=18, fontweight="bold")
plt.ylabel("Density", fontsize=18, fontweight="bold")
plt.grid(True, alpha=0.3)
plt.legend(fontsize=16)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
OUT_DIR = "/data/silvija/diffusion_results"
zr_real = np.load(os.path.join(OUT_DIR, "zr_features.npy"))
zr_generated_proj = np.load(os.path.join(OUT_DIR, "zr_features_gen.npy"))

plt.figure(figsize=(10,5))

plt.hist(zr_real.reshape(-1), bins=200, alpha=0.5,
         label="Real Z_R", density=True)

plt.hist(zr_generated_proj.reshape(-1), bins=200, alpha=0.5,
         label="Fake Z_R", density=True)

plt.title("Histogram: Real Z_R vs Diffusion Generated Z_R (Projected z_xml)",
          fontsize=16, fontweight="bold")

plt.xlabel("Value", fontsize=14, fontweight="bold")
plt.ylabel("Density", fontsize=14, fontweight="bold")

plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
zr_generated_orig = np.load(os.path.join(OUT_DIR, "zr_ctx_gen.npy"))

plt.figure(figsize=(10,5))

plt.hist(zr_real.reshape(-1), bins=200, alpha=0.5,
         label="Real Z_R", density=True)

plt.hist(zr_generated_orig.reshape(-1), bins=200, alpha=0.5,
         label="Fake Z_R", density=True)

plt.title("Histogram: Real Z_R vs Diffusion Generated Z_R (Original z_xml)",
          fontsize=16, fontweight="bold")

plt.xlabel("Value", fontsize=14, fontweight="bold")
plt.ylabel("Density", fontsize=14, fontweight="bold")

plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

OUT_DIR = "/data/silvija/diffusion_results"

zr_real = np.load(os.path.join(OUT_DIR, "zr_features.npy")).astype(np.float32)
zr_generated_proj = np.load(os.path.join(OUT_DIR, "zr_features_gen.npy")).astype(np.float32)

def cosine_distance_per_sample(a, b, eps=1e-8):
    a_norm = a / (np.linalg.norm(a, axis=1, keepdims=True) + eps)
    b_norm = b / (np.linalg.norm(b, axis=1, keepdims=True) + eps)
    cos_sim = np.sum(a_norm * b_norm, axis=1)
    cos_dist = 1.0 - cos_sim
    return cos_dist, cos_sim

cos_dist_proj, cos_sim_proj = cosine_distance_per_sample(zr_real, zr_generated_proj)

print("Projected z_xml -> generated z_R")
print("Mean cosine similarity:", cos_sim_proj.mean())
print("Std cosine similarity :", cos_sim_proj.std())
print("Mean cosine distance  :", cos_dist_proj.mean())
print("Std cosine distance   :", cos_dist_proj.std())

plt.figure(figsize=(10,5))
plt.hist(cos_dist_proj, bins=100, alpha=0.7, density=True, label="Projected z_xml")
plt.title("Histogram: Cosine Distance Between Real Z_R and Generated Z_R (Projected z_xml)",
          fontsize=16, fontweight="bold")
plt.xlabel("Cosine Distance", fontsize=14, fontweight="bold")
plt.ylabel("Density", fontsize=14, fontweight="bold")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Projected z_xml -> generated z_R
# Mean cosine similarity: 0.17146753
# Std cosine similarity : 0.08748878
# Mean cosine distance  : 0.8285325
# Std cosine distance   : 0.08748878

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

OUT_DIR = "/data/silvija/diffusion_results"

zr_real = np.load(os.path.join(OUT_DIR, "zr_features.npy")).astype(np.float32)
zr_generated_orig = np.load(os.path.join(OUT_DIR, "zr_ctx_gen.npy")).astype(np.float32)

def cosine_distance_per_sample(a, b, eps=1e-8):
    a_norm = a / (np.linalg.norm(a, axis=1, keepdims=True) + eps)
    b_norm = b / (np.linalg.norm(b, axis=1, keepdims=True) + eps)
    cos_sim = np.sum(a_norm * b_norm, axis=1)
    cos_dist = 1.0 - cos_sim
    return cos_dist, cos_sim

cos_dist_orig, cos_sim_orig = cosine_distance_per_sample(zr_real, zr_generated_orig)

print("Original z_xml -> generated z_R")
print("Mean cosine similarity:", cos_sim_orig.mean())
print("Std cosine similarity :", cos_sim_orig.std())
print("Mean cosine distance  :", cos_dist_orig.mean())
print("Std cosine distance   :", cos_dist_orig.std())

plt.figure(figsize=(10,5))
plt.hist(cos_dist_orig, bins=100, alpha=0.7, density=True, label="Original z_xml")
plt.title("Histogram: Cosine Distance Between Real Z_R and Generated Z_R (Original z_xml)",
          fontsize=16, fontweight="bold")
plt.xlabel("Cosine Distance", fontsize=14, fontweight="bold")
plt.ylabel("Density", fontsize=14, fontweight="bold")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Original z_xml -> generated z_R
# Mean cosine similarity: 0.010869787
# Std cosine similarity : 0.081396915
# Mean cosine distance  : 0.9891302
# Std cosine distance   : 0.081396915

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

OUT_DIR = "/data/silvija/diffusion_results"

zr_real = np.load(os.path.join(OUT_DIR, "zr_features.npy"))
zr_generated_proj = np.load(os.path.join(OUT_DIR, "zr_features_gen.npy"))

# compute MSE per sample
mse_proj = np.mean((zr_real - zr_generated_proj) ** 2, axis=1)

print("Projected z_xml")
print("Mean MSE:", mse_proj.mean())
print("Std MSE :", mse_proj.std())
print("Min MSE :", mse_proj.min())
print("Max MSE :", mse_proj.max())

plt.figure(figsize=(10,5))
plt.hist(mse_proj, bins=100, density=True)

plt.title("MSE Distance Histogram (Projected z_xml)",
          fontsize=18, fontweight="bold")
plt.xlabel("MSE Distance", fontsize=14, fontweight="bold")
plt.ylabel("Density", fontsize=14, fontweight="bold")

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Projected z_xml
# Mean MSE: 0.011661808
# Std MSE : 0.0012956418
# Min MSE : 0.00687842
# Max MSE : 0.017589826

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

OUT_DIR = "/data/silvija/diffusion_results"

zr_real = np.load(os.path.join(OUT_DIR, "zr_features.npy"))
zr_generated_orig = np.load(os.path.join(OUT_DIR, "zr_ctx_gen.npy"))

# compute MSE per sample
mse_orig = np.mean((zr_real - zr_generated_orig) ** 2, axis=1)

print("Original z_xml")
print("Mean MSE:", mse_orig.mean())
print("Std MSE :", mse_orig.std())
print("Min MSE :", mse_orig.min())
print("Max MSE :", mse_orig.max())

plt.figure(figsize=(10,5))
plt.hist(mse_orig, bins=100, density=True)

plt.title("MSE Distance Histogram (Original z_xml)",
          fontsize=18, fontweight="bold")
plt.xlabel("MSE Distance", fontsize=14, fontweight="bold")
plt.ylabel("Density", fontsize=14, fontweight="bold")

plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Original z_xml
# Mean MSE: 0.015455159
# Std MSE : 0.0012718268
# Min MSE : 0.010962122
# Max MSE : 0.020773854
